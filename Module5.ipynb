# %% [markdown]
# #why django should be used for web-development? Explain how you can create a project in Django?
#
# Ans - Django is the best framework for web applications, as it allows developers to use modules for faster development. As a developer, you can make use of these modules to create apps, websites from an existing source. It speeds up the development process greatly, as you do not have to code everything from scratch.
#
#
# Firstly,create virtual environment and activate that enviroment then install python.
#
# Use 'django-admin startproject project_name' command to create project.

# %% [markdown]
# #How to check install version of django?
#
# Ans- python -m django --version

# %% [markdown]
# #Mention what command line can be used to load data into Django?
#
# Ans-To load data into Django you have to use the command line Django-admin.py loaddata. The command line will searches the data and loads the contents of the named fixtures into the database.

# %% [markdown]
# #Explain what does django-admin.py make messages command is used for?
#
# Ans-The admin.py file is used to display your models in the Django admin panel. You can also customize your admin panel.

# %% [markdown]
# #What is .Django URLs?make program to create django urls. #INCOMPLETE
#
# Ans- In Django, views are Python functions which take a URL request as parameter and return an HTTP response or throw an exception like 404. Each view needs to be mapped to a corresponding URL pattern. This is done via a Python module called URLConf(URL configuration).

# %% [markdown]
# #What is Query set? Write program to create a new post object in database.
#
# Ans - A QuerySet is a collection of data from a database. A QuerySet is built up as a list of objects. QuerySets makes it easier to get the data you actually need, by allowing you to filter and order the data.
